# %% [markdown]
# <a href="https://colab.research.google.com/github/Coderkingkrishna/basic-c-programs/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a=np.array([1,2,3])
b=np.array([4,5,6])
c=np.concatenate((a,b))
print(c)
# Out:
# [1 2 3 4 5 6]

# %%
import numpy as np
a=np.array([[1,2],[3,4]])
b=np.array([[4,5],[6,7]])
c=np.concatenate((a,b),axis=1)
print(c)
# Out:
# [[1 2 4 5]
#  [3 4 6 7]]

# %%
import numpy as np
a=np.array([1,2,3])
b=np.array([4,5,6])
c=np.vstack((a,b))
print(c)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np
a=np.array([1,2,3,4,5,6])
c=np.array_split(a,4)
print(c)
# Out:
# [array([1, 2]), array([3, 4]), array([5]), array([6])]

# %%
import numpy as np
a=np.array([1,2,3,4,5,6])
c=a.copy()
a[0] = 12
print(a)
print(c)
# Out:
# [12  2  3  4  5  6]
# [1 2 3 4 5 6]

# %%
import numpy as np
a=np.array([1,2,3,4,5,6])
c=a.view()
a[0] = 12
print(a)
print(c)
# Out:
# [12  2  3  4  5  6]
# [12  2  3  4  5  6]

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,8])
y=np.array([3,10])
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,8])
y=np.array([3,10])
plt.plot(x,y,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,8])
y=np.array([3,10])
plt.plot(x,y,'p')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,8,1,10])
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,10])
plt.plot(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,8])
plt.plot(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,8])
y=np.array([3,10])
plt.plot(x,y,marker = 'o')
plt.show()
plt.plot(x,y,marker = '*')

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,8])
y=np.array([3,10])
plt.plot(x,y,'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,8])
y=np.array([3,10])
plt.plot(x,y,'s:m')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,8])
y=np.array([3,10])
plt.plot(x,y,marker = 'o', ms=20, mec='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,8,1,10])
plt.plot(x,y,linestyle = 'dotted',color = 'k',linewidth = '5')
plt.show()
plt.plot(x,y,linestyle = 'dashed')

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=np.array([1,2,6,8])
x2=np.array([3,5,6,1])
y1=np.array([3,8,1,10])
y2=np.array([6,7,4,1])
plt.plot(x1,y1,x2,y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,8,1,10])
plt.plot(x,y)
plt.xlabel("x->")
plt.ylabel("y->")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,8,1,10])
plt.plot(x,y)
plt.title("xy plot")
plt.xlabel("x->")
plt.ylabel("y->")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,8,1,10])
plt.plot(x,y)
plt.xlabel("x->")
plt.ylabel("y->")
plt.grid(axis = 'x')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("xy")
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("xy")
plt.suptitle("both axis")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,8,1,10])
plt.xlabel("x->")
plt.ylabel("y->")
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,8,1,10])
size=np.array([20,50,10,40])
plt.plot(x,y)
plt.xlabel("x->")
plt.ylabel("y->")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(['A','B','C','D'])
y=np.array([3,8,1,10])
plt.bar(x,y)
plt.xlabel("x->")
plt.ylabel("y->")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(['A','B','C','D'])
y=np.array([3,8,1,10])
plt.barh(x,y)
plt.xlabel("x->")
plt.ylabel("y->")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(['A','B','C','D'])
y=np.array([3,8,1,10])
plt.bar(x,y,color="black")
plt.xlabel("x->")
plt.ylabel("y->")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(['A','B','C','D'])
y=np.array([3,8,1,10])
plt.bar(x,y,width=0.2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([2,18,30,10])
y=np.array([3,8,1,10])
plt.scatter(x,y)
x=np.array([20,38,10,100])
y=np.array([31,28,1,110])
plt.scatter(x,y)
plt.xlabel("x->")
plt.ylabel("y->")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(['A','B','C','D'])
y=np.array([3,8,1,10])
plt.barh(x,y,height=0.2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.random.normal(3,8,10)
plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([3,8,1,10])
plt.pie(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([3,8,1,10])
y=["a","b","c","d"]
plt.pie(x,labels=y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([3,8,1,10])
y=["a","b","c","d"]
plt.pie(x,labels=y,startangle = 90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([3,8,1,10])
y=["a","b","c","d"]
ex=[0.22,0,0,0]
plt.pie(x,labels=y,explode = ex)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([3,8,1,10])
y=["a","b","c","d"]
ex=[0.22,0,0,0]
plt.pie(x,labels=y,explode = ex,shadow = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([3,8,1,10])
y=["a","b","c","d"]
plt.pie(x,labels=y)
plt.legend()
plt.show()
